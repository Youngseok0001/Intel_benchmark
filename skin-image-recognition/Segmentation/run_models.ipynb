# %% [markdown]
# ### Working environment
# >1. tensorflow 1.13.1
# >2. Python 3.6
# ### Dataset:
# > ISIC 2018: skin cancer images

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import tensorflow as tf
from attention_unet import *
from deeplab_model import *
from data_pipeline import *
from post_eval import mIOU, do_crf
import numpy as np
import os as os

# Select single gpu
os.environ["CUDA_VISIBLE_DEVICES"] = '3'
#config = tf.ConfigProto()
# Select multi gpu
config = tf.ConfigProto(log_device_placement=True, allow_soft_placement=True)
config.gpu_options.per_process_gpu_memory_fraction = 1.0
sess=tf.Session(config = config)

# Running with CPU
#config = tf.ConfigProto()
#config.intra_op_parallelism_threads = 44
#config.inter_op_parallelism_threads = 44
#tf.Session(config=config)

# %% [markdown]
# ### Build and compile models

# %%
tf.keras.backend.clear_session()
np.random.seed(609)
tf.set_random_seed(610)

train_test_ratio = 0.8
num_classes = 1
batch_size = 12
initial_epoch = 0
epochs = 10
init_lr = 2e-4
min_lr = 1e-7

loss = 'crossentropy'
metrics = ['jaccard_index',
           'pixelwise_sensitivity',
           'pixelwise_specificity']

# Make model


deeplab_model = Deeplabv3(metrics = metrics, loss=loss, lr= init_lr)
compile_model(deeplab_model, num_classes, metrics, loss, init_lr)


#deeplab_subpixel = deeplab_subpixel_method(metrics = metrics, loss=loss, lr=init_lr)    
#compile_model(deeplab_subpixel, num_classes, metrics, loss, init_lr)

# Attention U-Net

#att_unetmodel = attention_gating_unet2D(loss=loss, lr=init_lr ,metrics= metrics, num_classes=1, num_gpu=4)
#compile_model(att_unetmodel, num_classes, metrics, loss, init_lr)
# Out:
# WARNING:tensorflow:From /home/dianwen/.virtualenvs/3/lib/python3.6/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/dianwen/.virtualenvs/3/lib/python3.6/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %% [markdown]
# ### Split dataset and make data generator

# %%
# Make input generator
# make train-test split - set 8:2 split (return: data_path list)
imgs_train, label_train, imgs_test, label_test = split_datalist()

train_generator = create_generators(batch_size=batch_size, image_path=imgs_train, label_path=label_train,
                                    blur = 0, crop_shape = None, n_classes = 1,
                                    horizontal_flip = True, vertical_flip = True, brightness=0.1, 
                                    rotation=True, zoom=0.2, seed = 610, do_ahisteq = False)

valid_generator = create_generators(batch_size=batch_size, image_path=imgs_test, label_path=label_test,
                                    blur = 0, crop_shape = None, n_classes = 1, 
                                    horizontal_flip = False, vertical_flip = False, brightness= .0,
                                    rotation=False, zoom= 0., seed = 611, do_ahisteq = False)

#test_imgs, test_labs = load_resize_data(imgs_test, label_test)

# %%
def build_callbacks(tf_board = False):
    #checkpointer = ModelCheckpoint(filepath = '../Dir', verbose=1, save_best_only=True, save_weights_only=True,
    #                               monitor = 'val_{}'.format(monitor), mode = mode)
    stop_train = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', patience=10, verbose=1, mode = 'auto')
    reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                                     factor= 1-(1/np.exp(1)),
                                                     patience=2,
                                                     verbose=1,
                                                     mode='auto',
                                                     min_lr=1e-6)
    if tf_board:
        callbacks = [reduce_lr, stop_train, tensorboard]
    else:
        callbacks = [reduce_lr, stop_train]
    return callbacks

callbacks = build_callbacks(tf_board = False)

# %% [markdown]
# ### Training model

# %%
train_with_generator(model=deeplab_model, epochs=15, train_generator=train_generator,
                     valid_generator= valid_generator, callbacks= callbacks, mp = False)
# Out:
# WARNING:tensorflow:From /home/dianwen/.virtualenvs/3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 43/43 [==============================] - 28s 644ms/step - loss: 6.7613 - binary_jaccard_index: 0.6921 - binary_pixelwise_sensitivity: 0.9293 - binary_pixelwise_specificity: 0.8746
# 172/172 [==============================] - 150s 874ms/step - loss: 2.3651 - binary_jaccard_index: 0.7073 - binary_pixelwise_sensitivity: 0.8271 - binary_pixelwise_specificity: 0.8874 - val_loss: 6.7613 - val_binary_jaccard_index: 0.6921 - val_binary_pixelwise_sensitivity: 0.9293 - val_binary_pixelwise_specificity: 0.8746
# Epoch 2/15
# 43/43 [==============================] - 27s 632ms/step - loss: 2.0505 - binary_jaccard_index: 0.7769 - binary_pixelwise_sensitivity: 0.8199 - binary_pixelwise_specificity: 0.9770
# 172/172 [==============================] - 132s 765ms/step - loss: 1.4078 - binary_jaccard_index: 0.7974 - binary_pixelwise_sensitivity: 0.8626 - binary_pixelwise_specificity: 0.9434 - val_loss: 2.0505 - val_binary_jaccard_index: 0.7769 - val_binary_pixelwise_sensitivity: 0.8199 - val_binary_pixelwise_specificity: 0.9770
# Epoch 3/15
# 43/43 [==============================] - 31s 722ms/step - loss: 2.3588 - binary_jaccard_index: 0.7712 - binary_pixelwise_sensitivity: 0.8010 - binary_pixelwise_specificity: 0.9843
# 172/172 [==============================] - 135s 783ms/step - loss: 1.4311 - binary_jaccard_index: 0.7907 - binary_pixelwise_sensitivity: 0.8555 - binary_pixelwise_specificity: 0.9450 - val_loss: 2.3588 - val_binary_jaccard_index: 0.7712 - val_binary_pixelwise_sensitivity: 0.8010 - val_binary_pixelwise_specificity: 0.9843
# Epoch 4/15
# 43/43 [==============================] - 30s 708ms/step - loss: 1.6933 - binary_jaccard_index: 0.8103 - binary_pixelwise_sensitivity: 0.8474 - binary_pixelwise_specificity: 0.9635
# 172/172 [==============================] - 143s 831ms/step - loss: 1.2748 - binary_jaccard_index: 0.8137 - binary_pixelwise_sensitivity: 0.8661 - binary_pixelwise_specificity: 0.9494 - val_loss: 1.6933 - val_binary_jaccard_index: 0.8103 - val_binary_pixelwise_sensitivity: 0.8474 - val_binary_pixelwise_specificity: 0.9635
# Epoch 5/15
# 43/43 [==============================] - 29s 677ms/step - loss: 1.4804 - binary_jaccard_index: 0.8110 - binary_pixelwise_sensitivity: 0.8669 - binary_pixelwise_specificity: 0.9304
# 172/172 [==============================] - 139s 808ms/step - loss: 1.1787 - binary_jaccard_index: 0.8173 - binary_pixelwise_sensitivity: 0.8730 - binary_pixelwise_specificity: 0.9553 - val_loss: 1.4804 - val_binary_jaccard_index: 0.8110 - val_binary_pixelwise_sensitivity: 0.8669 - val_binary_pixelwise_specificity: 0.9304
# Epoch 6/15
# 43/43 [==============================] - 28s 651ms/step - loss: 1.4410 - binary_jaccard_index: 0.7694 - binary_pixelwise_sensitivity: 0.7813 - binary_pixelwise_specificity: 0.9715
# 172/172 [==============================] - 128s 744ms/step - loss: 1.1965 - binary_jaccard_index: 0.8100 - binary_pixelwise_sensitivity: 0.8706 - binary_pixelwise_specificity: 0.9501 - val_loss: 1.4410 - val_binary_jaccard_index: 0.7694 - val_binary_pixelwise_sensitivity: 0.7813 - val_binary_pixelwise_specificity: 0.9715
# Epoch 7/15
# 43/43 [==============================] - 29s 681ms/step - loss: 1.5548 - binary_jaccard_index: 0.7994 - binary_pixelwise_sensitivity: 0.8039 - binary_pixelwise_specificity: 0.9699
# 172/172 [==============================] - 130s 754ms/step - loss: 1.1393 - binary_jaccard_index: 0.8213 - binary_pixelwise_sensitivity: 0.8757 - binary_pixelwise_specificity: 0.9527 - val_loss: 1.5548 - val_binary_jaccard_index: 0.7994 - val_binary_pixelwise_sensitivity: 0.8039 - val_binary_pixelwise_specificity: 0.9699
# Epoch 8/15
# 43/43 [==============================] - 30s 687ms/step - loss: 2.0857 - binary_jaccard_index: 0.7238 - binary_pixelwise_sensitivity: 0.7576 - binary_pixelwise_specificity: 0.9592
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00012642410857196984.
# 172/172 [==============================] - 138s 801ms/step - loss: 1.2555 - binary_jaccard_index: 0.8168 - binary_pixelwise_sensitivity: 0.8716 - binary_pixelwise_specificity: 0.9502 - val_loss: 2.0857 - val_binary_jaccard_index: 0.7238 - val_binary_pixelwise_sensitivity: 0.7576 - val_binary_pixelwise_specificity: 0.9592
# Epoch 9/15
# 43/43 [==============================] - 30s 698ms/step - loss: 1.5633 - binary_jaccard_index: 0.8195 - binary_pixelwise_sensitivity: 0.8806 - binary_pixelwise_specificity: 0.9624
# 172/172 [==============================] - 138s 803ms/step - loss: 1.1532 - binary_jaccard_index: 0.8211 - binary_pixelwise_sensitivity: 0.8749 - binary_pixelwise_specificity: 0.9568 - val_loss: 1.5633 - val_binary_jaccard_index: 0.8195 - val_binary_pixelwise_sensitivity: 0.8806 - val_binary_pixelwise_specificity: 0.9624
# Epoch 10/15
# 43/43 [==============================] - 29s 684ms/step - loss: 1.4846 - binary_jaccard_index: 0.8130 - binary_pixelwise_sensitivity: 0.8820 - binary_pixelwise_specificity: 0.9292
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 7.991528195081896e-05.
# 172/172 [==============================] - 137s 799ms/step - loss: 1.0059 - binary_jaccard_index: 0.8374 - binary_pixelwise_sensitivity: 0.8840 - binary_pixelwise_specificity: 0.9567 - val_loss: 1.4846 - val_binary_jaccard_index: 0.8130 - val_binary_pixelwise_sensitivity: 0.8820 - val_binary_pixelwise_specificity: 0.9292
# Epoch 11/15
# 43/43 [==============================] - 28s 652ms/step - loss: 1.7243 - binary_jaccard_index: 0.8010 - binary_pixelwise_sensitivity: 0.8151 - binary_pixelwise_specificity: 0.9639
# 172/172 [==============================] - 133s 775ms/step - loss: 0.9578 - binary_jaccard_index: 0.8328 - binary_pixelwise_sensitivity: 0.8804 - binary_pixelwise_specificity: 0.9581 - val_loss: 1.7243 - val_binary_jaccard_index: 0.8010 - val_binary_pixelwise_sensitivity: 0.8151 - val_binary_pixelwise_specificity: 0.9639
# Epoch 12/15
# 43/43 [==============================] - 27s 634ms/step - loss: 2.2561 - binary_jaccard_index: 0.8262 - binary_pixelwise_sensitivity: 0.8622 - binary_pixelwise_specificity: 0.9582
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 5.0516093983885184e-05.
# 172/172 [==============================] - 128s 746ms/step - loss: 0.9661 - binary_jaccard_index: 0.8348 - binary_pixelwise_sensitivity: 0.8826 - binary_pixelwise_specificity: 0.9561 - val_loss: 2.2561 - val_binary_jaccard_index: 0.8262 - val_binary_pixelwise_sensitivity: 0.8622 - val_binary_pixelwise_specificity: 0.9582
# Epoch 13/15
# 43/43 [==============================] - 28s 643ms/step - loss: 1.3382 - binary_jaccard_index: 0.8290 - binary_pixelwise_sensitivity: 0.8867 - binary_pixelwise_specificity: 0.9366
# 172/172 [==============================] - 129s 752ms/step - loss: 1.0259 - binary_jaccard_index: 0.8387 - binary_pixelwise_sensitivity: 0.8787 - binary_pixelwise_specificity: 0.9530 - val_loss: 1.3382 - val_binary_jaccard_index: 0.8290 - val_binary_pixelwise_sensitivity: 0.8867 - val_binary_pixelwise_specificity: 0.9366
# Epoch 14/15
# 43/43 [==============================] - 27s 636ms/step - loss: 1.7117 - binary_jaccard_index: 0.8062 - binary_pixelwise_sensitivity: 0.8822 - binary_pixelwise_specificity: 0.9472
# 172/172 [==============================] - 128s 746ms/step - loss: 0.8935 - binary_jaccard_index: 0.8436 - binary_pixelwise_sensitivity: 0.8912 - binary_pixelwise_specificity: 0.9559 - val_loss: 1.7117 - val_binary_jaccard_index: 0.8062 - val_binary_pixelwise_sensitivity: 0.8822 - val_binary_pixelwise_specificity: 0.9472
# Epoch 15/15
# 43/43 [==============================] - 30s 689ms/step - loss: 1.3044 - binary_jaccard_index: 0.8244 - binary_pixelwise_sensitivity: 0.8542 - binary_pixelwise_specificity: 0.9672
# 172/172 [==============================] - 129s 752ms/step - loss: 0.8184 - binary_jaccard_index: 0.8517 - binary_pixelwise_sensitivity: 0.8943 - binary_pixelwise_specificity: 0.9560 - val_loss: 1.3044 - val_binary_jaccard_index: 0.8244 - val_binary_pixelwise_sensitivity: 0.8542 - val_binary_pixelwise_specificity: 0.9672

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# read test image
pred_img = cv2.imread(imgs_test[2])
pred_img = cv2.resize(pred_img, (224,224))
pred_img = cv2.cvtColor(pred_img, cv2.COLOR_BGR2RGB)

# generate test segmentation
pred = deeplab_model.predict(np.expand_dims(pred_img, axis=0))
pred = np.squeeze(pred)
# Thresholding
pred_threshold = (pred > 0.5).astype(np.int8)
MAP = do_crf(pred_img, pred_threshold.astype('int32'), zero_unsure=False)

# %%
plt.imshow(pred_img)
plt.imshow(MAP, alpha=0.2)

# %%
pred_lab1 = cv2.imread(label_test[2])
pred_lab2 = cv2.resize(pred_lab1, (224,224))
pred_lab = cv2.resize(pred_threshold.astype(np.uint8), (pred_lab1.shape[1], pred_lab1.shape[0]))

# %%
plt.imshow(pred_lab2)
plt.imshow(pred_threshold, alpha=0.2)

# %%
plt.imshow(pred_lab1)
plt.imshow(pred_lab, alpha=0.2)

# %%
plt.imshow(pred_img)
plt.imshow(pred_lab2, alpha=0.)
